# %% [markdown]
# # Import required libraries

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from time import sleep

# %% [markdown]
# # Open the browser and Navigate the webpage

# %%
chrome_options = Options()
chrome_options.add_experimental_option("detach",True)

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),options=chrome_options)
driver.get('https://www.google.com/search?q=restaurants+in+new+york+usa+google+maps&sca_esv=601425548&rlz=1C1CHBD_enIN1020IN1020&biw=1366&bih=633&tbm=lcl&sxsrf=ACQVn0-FrJxG3ZjDv7qFavNr1LC1_sgUhw%3A1706201915367&ei=O5OyZbqJFc_V4-EP3NWWyAk&oq=restaurants+in+new+york+usa+google+&gs_lp=Eg1nd3Mtd2l6LWxvY2FsIiNyZXN0YXVyYW50cyBpbiBuZXcgeW9yayB1c2EgZ29vZ2xlICoCCAAyBRAhGKABMgUQIRigAUiJOFDzEVi2KHAAeACQAQCYAYUCoAG-DqoBBTAuNC41uAEByAEA-AEBwgIEECMYJ8ICBhAAGBYYHsICCxAAGIAEGIoFGIYDwgIHECEYChigAYgGAQ&sclient=gws-wiz-local#rlfi=hd:;si:;mv:[[40.7717958,-73.9745172],[40.705006499999996,-74.0162524]];tbs:lrf:!1m4!1u3!2m2!3m1!1e1!2m1!1e3!3sIAE,lf:1,lf_ui:4')
sleep(5)
driver.maximize_window()

# %%
names = []
add = []
num = []
web = []
direct = []

# %%
driver.refresh()
for i in range(4, 46, 2):
    try:
        rest = driver.find_element(By.XPATH,'/html/body/div[4]/div/div[9]/div[1]/div/div[2]/div[2]/div/div/div/div/div/div/div/div/div[1]/div[3]/div[{0}]/div[2]/div/div/a'.format(str(i)))
        rest.click()
    except:
        print(" ")
            
    try:
        name = driver.find_element(By.XPATH,'//h2/span')
        names.append(name.text)
    except:
        names.append(" ")
            
    try: 
        address = driver.find_element(By.XPATH,'//span[@class="LrzXr"]')
        add.append(address.text)
    except:
        add.append(" ")
            
    try:
        number = driver.find_element(By.XPATH,'//span[@class="LrzXr zdqRlf kno-fv"]/a/span')
        num.append(number.text)
    except:
        num.append(" ")
        
    try: 
        website = driver.find_element(By.XPATH,'/html/body/div[4]/div/div[9]/div[1]/div/div[2]/div[2]/div/div/div/div/div/div/div/div/div[1]/div[3]/div[{0}]/div[2]/div/a[1]'.format(str(i))).get_attribute('href')
        web.append(website)
    except:
        web.append(" ")
            
    try:
        direction = driver.find_element(By.XPATH,'/html/body/div[4]/div/div[9]/div[1]/div/div[2]/div[2]/div/div/div/div/div/div/div/div/div[1]/div[3]/div[{0}]/div[2]/div/a[2]'.format(str(i))).get_attribute('href')
        direct.append(direction)
    except:
        direct.append(" ")
        
    sleep(3)

# %%
data = pd.DataFrame()
data['Restaurants Name'] = names
data['Address'] = add
data['Mob. Number'] = num
data['Website url'] = web
data['Location link'] = direct

# %%
data['Website url'] = data['Website url'].shift(1)
data['Location link'] = data['Location link'].shift(1)

# %%
datas = data.drop(data.index[0])

# %%
datas
# Out:
#               Restaurants Name  \
# 1                       Per Se
# 2                       ROBERT
# 3                   The Modern
# 4                       Upland
# 5              Gramercy Tavern
# 6                       Estela
# 7                    Le Coucou
# 8   Schilling Restaurant & Bar
# 9                        Craft
# 10               Trinity Place
# 11       Blue Ribbon Brasserie
# 12                      Vestry
# 13                Le Bernardin
# 14           DK Restaurant NYC
# 15                       Prune
# 16      COTE Korean Steakhouse
# 17    Family Meal at Blue Hill
# 18                      Oceana
# 19                       Cosme
# 20                       Cosme
#
#                                               Address      Mob. Number  \
# 1   10 Columbus Cir, New York, NY 10019, United St...
# 2   2 Columbus Cir, New York, NY 10019, United States  +1 212-299-7730
# 3      9 W 53rd St, New York, NY 10019, United States  +1 212-333-1220
# ...

# %%
datas.to_csv("NYC_restuarants.csv")

# %%
for j in range(1,10):
    nxt = driver.find_element(By.XPATH,'//a[@id="pnnext"]')
    nxt.click()
    driver.refresh()
    sleep(3)
    for k in range(4, 42, 2):
        try:
            res = driver.find_element(By.XPATH,'/html/body/div[4]/div/div[9]/div[1]/div/div[2]/div[2]/div/div/div/div/div/div/div/div/div/div[1]/div[3]/div[{0}]/div[2]/div/div/a'.format(str(k)))
            res.click()
        except:
            print("Not Found")
            
        try:
            nam = driver.find_element(By.XPATH,'//h2/span')
            print(nam.text)
        except:
            print("N/A")
            
        try: 
            addres = driver.find_element(By.XPATH,'//span[@class="LrzXr"]')
            print(addres.text)
        except:
            print("N/A")
            
        try:
            numbe = driver.find_element(By.XPATH,'//span[@class="LrzXr zdqRlf kno-fv"]/a/span')
            print(numbe.text)
        except:
            print("N/A")
        
        try: 
            websit = driver.find_element(By.XPATH,'/html/body/div[4]/div/div[9]/div[1]/div/div[2]/div[2]/div/div/div/div/div/div/div/div/div/div[1]/div[3]/div[{0}]/div[2]/div/a[1]'.format(str(k))).get_attribute('href')
            print(websit)
        except:
            print("Not Found")
            
        try:
            directio = driver.find_element(By.XPATH,'/html/body/div[4]/div/div[9]/div[1]/div/div[2]/div[2]/div/div/div/div/div/div/div/div/div/div[1]/div[3]/div[{0}]/div[2]/div/a[2]'.format(str(k))).get_attribute('href')
            print(direction)
        except:
            directio = " "
        
        sleep(3)
# Out:
# N/A
# N/A
# N/A
# https://www.thegrillnewyork.com/?utm_medium=Click&utm_source=GoogleMyBusiness
# https://www.google.com/maps/dir//Cosme,+35+E+21st+St,+New+York,+NY+10010,+United+States/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x89c259a16418e84f:0x3532988b2d0befec?sa=X&ved=2ahUKEwit99Px1IqEAxX9k1YBHcxQB3oQ48ADegQIBRAA
# THE GRILL
# Seagram Building, 99 E 52nd St, New York, NY 10022, United States
# +1 212-254-3000
# http://wildair.nyc/
# https://www.google.com/maps/dir//Cosme,+35+E+21st+St,+New+York,+NY+10010,+United+States/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x89c259a16418e84f:0x3532988b2d0befec?sa=X&ved=2ahUKEwit99Px1IqEAxX9k1YBHcxQB3oQ48ADegQIBRAA
# Wildair
# 142 Orchard St, New York, NY 10002, United States
# +1 646-964-5624
# https://aifiorinyc.com/?utm_source=GoogleBusinessProfile&utm_medium=Website&utm_campaign=MapLabs
# ...

# %%
driver.quit()
